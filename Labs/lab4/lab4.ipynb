# %% [markdown]
# # Лабораторна робота №4
#
# ### Студента групи МІТ-31 (підгрупа 1)
#
# ### Добровольського Арсенія Михайловича
#
# ## Завдання
# 1. Загальні операції з TensorFlow:
#
#    a. Створення тензорів:
#       - Створити тензори різних розмірів та форм (скаляр, вектор, матриця) зі значеннями за замовчуванням або випадковими значеннями.
#       - Використати константи, змінні, або інші функції для створення тензорів.
#
#    b. Операції з тензорами:
#       - Виконати операції додавання, віднімання, множення, та ділення між тензорами.
#       - Застосувати математичні функції (наприклад, синус, косинус) до тензорів.
#
#    c. Індексація та зрізи:
#       - Звернутися до окремих елементів в тензорах та зрізати їх для отримання підмножини даних.
#
#    d. Зміна форми тензорів:
#       - Змінити розмір та форму тензорів (решейп) для підготовки їх до подальших операцій.

# %%
import tensorflow as tf

# a. Creating tensors
print("-----------------------------------------------------------------------------------------------")
print("CREATING TENSORS")
scalar = tf.constant(56)
s_rank = tf.rank(scalar)
print("Scalar: ", scalar)
print("Scalar rank: ", s_rank)

vector = tf.Variable([7, 13, 19, 25, 31])
v_rank = tf.rank(vector)
print("\nVector: ", vector)
print("Vector rank: ", v_rank)

vector_r = tf.random.uniform(shape=(5,), minval=1, maxval=10, dtype=tf.int32)
print("\nRandom vector: ", vector_r)

matrix = tf.Variable([[5, 3, 2], [4, 7, 9], [1, 8, 6]])
m_rank = tf.rank(matrix)
print("\nMatrix: ")
print(matrix)
print("Matrix rank: ", m_rank)

matrix_r = tf.random.uniform(shape=(3, 3), minval=1, maxval=10, dtype=tf.int32)
print("\nRandom matrix: ")
print(matrix_r)

tensor_3d = tf.Variable([[[7, 6, 5], [2, 8, 4]], [[3, 7, 6], [1, 3, 9]]])
tensor_3d_rank = tf.rank(tensor_3d)
print("\n3D Tensor:")
print(tensor_3d)
print("3D Tensor rank: ", tensor_3d_rank)

tensor_3d_r = tf.random.uniform(shape=(2, 2, 3), minval=1, maxval=10, dtype=tf.int32)
print("\nRandom 3D Tensor:")
print(tensor_3d_r)

# b. Operations with tensors
print("\n-----------------------------------------------------------------------------------------------")
print("OPERATIONS WITH TENSORS")

addition = tf.add(vector, vector_r)
print("\nAddition: ")
print(addition)

substraction = tf.subtract(matrix, matrix_r)
print("\nSubstraction: ")
print(substraction)

multiplication_1 = tf.matmul(matrix, matrix_r)
print("\nMatrix multiplication: ")
print(multiplication_1)

multiplication_2 = tf.multiply(tensor_3d, tensor_3d_r)
print("\nElement-wise multiplication: ")
print(multiplication_2)

division = tf.divide(tensor_3d, tensor_3d_r)
print("\nDivision: ")
print(division)

vector = tf.cast(vector, tf.float64)
sin_vector = tf.sin(vector)
print("\nSin of the vector:")
print(sin_vector)

tensor_3d = tf.cast(tensor_3d, tf.float64)
cos_tensor_3d = tf.cos(tensor_3d)
print("\nCosine of a 3D Tensor: ")
print(cos_tensor_3d)

# c. Indexing and slices
print("\n-----------------------------------------------------------------------------------------------")
print("INDEXING AND SLICES")

# Accessing a specific element in tensor (matrix)
element = matrix[1, 2]
print("\nElement of matrix at position (1, 2):", element)

# Tensor slice
slice_tensor_1 = tensor_3d[1, 0, :]
print("Sliced tensor (Pythonic way):", slice_tensor_1)

slice_tensor_2 = tf.slice(tensor_3d_r, begin=[1, 0, 0], size=[1, 1, 2])
print("Sliced tensor (tf.slice):", slice_tensor_2)

# d. Reshaping a tensor
print("\n-----------------------------------------------------------------------------------------------")
print("RESHAPING")

print("\nOriginal tensor: ")
print(tensor_3d)

tensor_reshaped = tf.reshape(tensor_3d, (3, 2, 2))
print("\nReshaped tensor: ")
print(tensor_reshaped)
# Out:
# -----------------------------------------------------------------------------------------------
# CREATING TENSORS
# Scalar:  tf.Tensor(56, shape=(), dtype=int32)
# Scalar rank:  tf.Tensor(0, shape=(), dtype=int32)
#
# Vector:  <tf.Variable 'Variable:0' shape=(5,) dtype=int32, numpy=array([ 7, 13, 19, 25, 31])>
# Vector rank:  tf.Tensor(1, shape=(), dtype=int32)
#
# Random vector:  tf.Tensor([8 7 1 6 2], shape=(5,), dtype=int32)
#
# Matrix:
# <tf.Variable 'Variable:0' shape=(3, 3) dtype=int32, numpy=
# array([[5, 3, 2],
#        [4, 7, 9],
#        [1, 8, 6]])>
# Matrix rank:  tf.Tensor(2, shape=(), dtype=int32)
#
# Random matrix:
# tf.Tensor(
# [[4 9 5]
#  [6 4 5]
#  [4 9 6]], shape=(3, 3), dtype=int32)
#
# 3D Tensor:
# <tf.Variable 'Variable:0' shape=(2, 2, 3) dtype=int32, numpy=
# array([[[7, 6, 5],
#         [2, 8, 4]],
#
#        [[3, 7, 6],
#         [1, 3, 9]]])>
# 3D Tensor rank:  tf.Tensor(3, shape=(), dtype=int32)
#
# Random 3D Tensor:
# tf.Tensor(
# [[[1 6 3]
#   [8 4 9]]
# ...

# %% [markdown]
# 2. Глибше ознайомлення з TensorFlow:
#
#    a. Регресія:
#       - Згенерувати синтетичний набір даних для задачі регресії, включаючи ознаки та відповідні значення цільової змінної.
#       - Створити послідовну модель нейронної мережі з Dense шарами для регресії.
#       - Вибрати функцію втрати та оптимізатор для навчання моделі регресії.
#       - Навчити модель та оцінити її регресійну точність.
#
#    b. Класифікація:
#       - Згенерувати синтетичний набір даних для задачі бінарної класифікації, включаючи ознаки та мітки класів.
#       - Створити послідовну модель нейронної мережі з Dense шарами для класифікації.
#       - Вибрати функцію втрати, оптимізатор та метрики для навчання моделі класифікації.
#       - Навчити модель та оцінити її класифікаційну точність.

# %% [markdown]
# 3. Графічний аналіз наборів даних:
#
#    a. Візуалізація даних:
#       - Використати бібліотеку Matplotlib для створення різних видів графіків, таких як scatter plot, гістограми, лінійні графіки, які відображають дані з набору даних.
#       - Показати взаємозв'язки між ознаками або класами на графіках.
#
#    b. Візуалізація результів:
#       - Побудувати графіки, що відображають реальні та передбачені значення для задачі регресії або матриці плутанини для задачі класифікації.
#       - Додати підписи, легенду та інші елементи для покращення зрозуміння графіків.

# %% [markdown]
# **Regression**

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
from sklearn.datasets import make_regression
from sklearn.model_selection import train_test_split
from keras.models import Sequential
from keras.layers import Dense

# Data generation
X, y = make_regression(n_samples=2000, n_features=5, noise=10, random_state=42)
df = pd.DataFrame(data=X, columns=[f'Feature{i+1}' for i in range(5)])
df['Target'] = y
df.to_csv('data_regression.csv', index=False)

X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.2, random_state=10)

# Model creation
model = Sequential([
    Dense(64, activation='relu', input_shape=(5,)),
    Dense(32, activation='relu'),
    Dense(1)
])

# Choosing loss function, optimizer and metrics for regression
model.compile(optimizer='adam', loss='mean_squared_error', metrics=['mae'])
model.summary()

# Fitting the model
history = model.fit(X_train, y_train, epochs=100, validation_data=(X_test, y_test), batch_size=32)

# Regression accuracy evaluation
train_loss = model.evaluate(X_train, y_train, verbose=0)
print("\nTraining Loss (MSE) on Training Data:", train_loss)
test_loss = model.evaluate(X_test, y_test, verbose=0)
print("Test Loss (MSE) on Test Data:", test_loss)

# -------------------------------------------------------------------------------------------------
# DATA VISUALIZATION
# -------------------------------------------------------------------------------------------------
# Correlation matrix
data = pd.read_csv('data_regression.csv')
correlation_matrix = data.corr()
plt.figure(figsize=(10, 8))
sns.heatmap(correlation_matrix, annot=True, cmap='viridis')
plt.title('Correlation matrix')
plt.show()

# Pairplot
sns.pairplot(data)
plt.show()

# Scatter Plot: Feature 1 VS Feature 2
plt.figure(figsize=(12, 5))
plt.subplot(1, 2, 1)
plt.scatter(data['Feature1'], data['Feature2'], c=data['Target'], cmap='viridis', s=100)
plt.colorbar(label='Target')
plt.xlabel('Feature 1')
plt.ylabel('Feature 2')
plt.title('Scatter Plot: Feature 1 VS Feature 2')

# Scatter Plot Of Real VS Predicted Values
y_pred = model.predict(X_test)
distances = np.abs(y_test - y_pred) # Distance between real and predicted values
max_distance = np.max(distances) # For setting transparency
plt.subplot(1, 2, 2)
for i in range(len(y_test)):
    alpha = 1 - (distances[i] / max_distance)  # Transparency which depends on the distance
    plt.scatter(y_test[i], y_pred[i], c='orange', alpha=alpha)

plt.plot([min(y_test), max(y_test)], [min(y_pred), max(y_pred)], linestyle='--', color = 'blue')
plt.title("Scatter Plot Of Real VS Predicted Values")
plt.xlabel("Real Values")
plt.ylabel("Predicted Values")
plt.tight_layout()
plt.show()

# MSE loss function plot on train and validation data
plt.figure(figsize=(12, 5))
plt.plot(history.history['loss'], label='Train Loss')
plt.plot(history.history['val_loss'], label='Validation Loss')
plt.title('Model Loss')
plt.xlabel('Epochs')
plt.ylabel('MSE')
plt.legend()
# Out:
# Model: "sequential_22"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# ...
#  dense_65 (Dense)            (None, 64)                384
#
#  dense_66 (Dense)            (None, 32)                2080
#
#  dense_67 (Dense)            (None, 1)                 33
#
# ...
# Total params: 2497 (9.75 KB)
# Trainable params: 2497 (9.75 KB)
# Non-trainable params: 0 (0.00 Byte)
# _________________________________________________________________
# Epoch 1/100
# 50/50 [==============================] - 2s 11ms/step - loss: 4533.4434 - mae: 53.5698 - val_loss: 4693.9961 - val_mae: 53.7337
# Epoch 2/100
# 50/50 [==============================] - 0s 4ms/step - loss: 4280.5083 - mae: 51.9631 - val_loss: 4246.4214 - val_mae: 50.9031
# Epoch 3/100
# 50/50 [==============================] - 0s 3ms/step - loss: 3542.4998 - mae: 46.9135 - val_loss: 3110.1763 - val_mae: 42.9630
# Epoch 4/100
# ...

# %% [markdown]
# **Classification**

# %%
from sklearn.datasets import make_classification
from sklearn.model_selection import train_test_split
from sklearn.metrics import accuracy_score, confusion_matrix

X, y = make_classification(
    n_samples=2000, 
    n_features=2, 
    n_informative=2,
    n_redundant=0, 
    n_classes=2, 
    random_state=25
)

data = pd.DataFrame(data=X, columns=[f'Feature{i+1}' for i in range(2)])
data['Target'] = y
data.to_csv('data_classification.csv', index=False)

X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.2, random_state=10)

model = Sequential([
    Dense(64, activation='relu', input_shape=(2,)),
    Dense(32, activation='relu'),
    Dense(1, activation='sigmoid')
])

model.compile(optimizer='adam', loss='binary_crossentropy', metrics=['accuracy'])
model.summary()

history = model.fit(X_train, y_train, epochs=50, validation_data=(X_test, y_test), batch_size=32, verbose=0)

y_pred = (model.predict(X_test) > 0.5).astype("int32")
accuracy = accuracy_score(y_test, y_pred)
print(f'Accuracy: {accuracy}')

train_loss = model.evaluate(X_train, y_train, verbose=0)
print("\nTraining Loss (MSE) on Training Data:", train_loss)
test_loss = model.evaluate(X_test, y_test, verbose=0)
print("Test Loss (MSE) on Test Data:", test_loss)

# Pairplot
data = pd.read_csv('data_classification.csv')
sns.pairplot(data)
plt.show()

# Confusion matrix
conf_matrix = confusion_matrix(y_test, y_pred)
sns.heatmap(conf_matrix, annot=True, fmt='d', cmap='viridis',
            xticklabels=['Predicted 0', 'Predicted 1'],
            yticklabels=['Actual 0', 'Actual 1'])
plt.xlabel('Predicted')
plt.ylabel('Actual')
plt.title('Confusion Matrix')
plt.show()

# MSE loss function plot on train and validation data
plt.figure(figsize=(12, 6))
plt.plot(history.history['loss'], label='Train Loss')
plt.plot(history.history['val_loss'], label='Validation Loss')
plt.title('Model Loss')
plt.xlabel('Epochs')
plt.ylabel('MSE')
plt.legend()
plt.show()
# Out:
# Model: "sequential_23"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# ...
#  dense_68 (Dense)            (None, 64)                192
#
#  dense_69 (Dense)            (None, 32)                2080
#
#  dense_70 (Dense)            (None, 1)                 33
#
# ...
# Total params: 2305 (9.00 KB)
# Trainable params: 2305 (9.00 KB)
# Non-trainable params: 0 (0.00 Byte)
# _________________________________________________________________
# 13/13 [==============================] - 0s 3ms/step
# Accuracy: 0.9625
#
# Training Loss (MSE) on Training Data: [0.1115896999835968, 0.9674999713897705]
# Test Loss (MSE) on Test Data: [0.1211339458823204, 0.9624999761581421]
